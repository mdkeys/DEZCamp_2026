# %%
import pandas as pd

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet"

# %%
columns = ['PULocationID', 'DOLocationID', 'trip_distance', 'total_amount', 'tpep_pickup_datetime']
df = pd.read_parquet(url, columns=columns).head(1000)

# %%
df.head()
# Out:
#    PULocationID  DOLocationID  trip_distance  total_amount  \
# 0            43           186           1.68         22.15
# 1           142           237           2.28         24.94
# 2           163           238           2.70         25.62
# 3           138           261          12.87         86.14
# 4           138            37           8.40         48.65
#
#   tpep_pickup_datetime
# 0  2025-11-01 00:13:25
# 1  2025-11-01 00:49:07
# 2  2025-11-01 00:07:19
# 3  2025-11-01 00:00:00
# 4  2025-11-01 00:18:50

# %%
row = df.iloc[0]
row
# Out:
# PULocationID                             43
# DOLocationID                            186
# trip_distance                          1.68
# total_amount                          22.15
# tpep_pickup_datetime    2025-11-01 00:13:25
# Name: 0, dtype: object

# %%
row.tpep_pickup_datetime.timestamp()
# Out:
# 1761956005.0

# %%
from dataclasses import dataclass

# %%
# Represent it as a python class

@dataclass
class Ride:
    PULocationID: int
    DOLocationID: int
    trip_distance: float
    total_amount: float
    tpep_pickup_datetime: int  # epoch milliseconds

# %%
# Example event that occurs. After this, we want to send to our stream for processing.
ride = Ride(
    PULocationID=1,
    DOLocationID=10,
    trip_distance=10,
    total_amount=20,
    tpep_pickup_datetime=1761956005000
)

# %%
import json

def json_serializer(data):
    return json.dumps(data).encode('utf-8')

# %%
from kafka import KafkaProducer

server = 'localhost:9092'

producer = KafkaProducer(
    bootstrap_servers=[server],
    value_serializer=json_serializer #turns our data into string
)

# %%
import dataclasses

# Topic = synonum for stream. Think of it like a pipe. And on the other side of the pipe, we have a consumer that is consuming the data and doing something with it. 
topic_name = 'rides'

producer.send(topic_name, value=dataclasses.asdict(ride))
producer.flush()
