# %% [markdown]
# Use this file to test which columns in the homework have missing values that I need to deal with

# %%
import pandas as pd

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-10.parquet"
columns = ['lpep_pickup_datetime', 'lpep_dropoff_datetime', 'PULocationID', 'DOLocationID', 'passenger_count', 'trip_distance', 'tip_amount', 'total_amount']
df = pd.read_parquet(url, columns=columns)

# %%
print(df[columns].isnull().sum())
# Out:
# lpep_pickup_datetime        0
# lpep_dropoff_datetime       0
# PULocationID                0
# DOLocationID                0
# passenger_count          5015
# trip_distance               0
# tip_amount                  0
# total_amount                0
# dtype: int64

# %%
#hw question 3 since my files are not getting it right...
over_5km = df[df['trip_distance'] > 5.0]
print(f"Trips with trip_distance > 5km: {len(over_5km)}")
# Out:
# Trips with trip_distance > 5km: 8506
